# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\All Merged.csv')

# %%
df_need_state_5 = df[df['Need States'] == 'Need State 5']

# %%
df_need_state_5
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# 9    2021     2  2021-01-11  Need State 5   601776.75         1049389.50
# 14   2021     3  2021-01-18  Need State 5   670983.00         1050538.50
# 19   2021     4  2021-01-25  Need State 5   624003.00         1042530.00
# 24   2021     5  2021-02-01  Need State 5   602572.50         1041183.75
# ..    ...   ...         ...           ...         ...                ...
# 704  2023    37  2023-09-11  Need State 5  1501643.25         1794207.00
# 709  2023    38  2023-09-18  Need State 5  1476577.50         1657944.00
# 714  2023    39  2023-09-25  Need State 5  1426885.50         1442409.75
# 719  2023    40  2023-10-02  Need State 5  1386183.75         1373699.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)      Sales  Trade Spend
# ...

# %%
df_need_state_5["Sales/Trade Spend"] = df_need_state_5["Sales"]/df_need_state_5["Trade Spend"]
# Out:
# C:\Users\TianM\AppData\Local\Temp\ipykernel_4080\3116227976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_need_state_5["Sales/Trade Spend"] = df_need_state_5["Sales"]/df_need_state_5["Trade Spend"]

# %%
df_need_state_5
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# 9    2021     2  2021-01-11  Need State 5   601776.75         1049389.50
# 14   2021     3  2021-01-18  Need State 5   670983.00         1050538.50
# 19   2021     4  2021-01-25  Need State 5   624003.00         1042530.00
# 24   2021     5  2021-02-01  Need State 5   602572.50         1041183.75
# ..    ...   ...         ...           ...         ...                ...
# 704  2023    37  2023-09-11  Need State 5  1501643.25         1794207.00
# 709  2023    38  2023-09-18  Need State 5  1476577.50         1657944.00
# 714  2023    39  2023-09-25  Need State 5  1426885.50         1442409.75
# 719  2023    40  2023-10-02  Need State 5  1386183.75         1373699.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)      Sales  Trade Spend  \
# ...

# %%
sns.lineplot(data = df_need_state_5, x='Date', y='Sales/Trade Spend')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
df_need_state_5.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\Trade Spend Sales.csv', index=False)

# %%
df_pos = df[df['Need States'] == 'Need State 5']

# %%
df_pos
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# 9    2021     2  2021-01-11  Need State 5   601776.75         1049389.50
# 14   2021     3  2021-01-18  Need State 5   670983.00         1050538.50
# 19   2021     4  2021-01-25  Need State 5   624003.00         1042530.00
# 24   2021     5  2021-02-01  Need State 5   602572.50         1041183.75
# ..    ...   ...         ...           ...         ...                ...
# 704  2023    37  2023-09-11  Need State 5  1501643.25         1794207.00
# 709  2023    38  2023-09-18  Need State 5  1476577.50         1657944.00
# 714  2023    39  2023-09-25  Need State 5  1426885.50         1442409.75
# 719  2023    40  2023-10-02  Need State 5  1386183.75         1373699.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)      Sales  Trade Spend
# ...

# %%
df_pos["Factory POS/Trade Spend"] = df_pos["Factory POS"]/df_pos["Trade Spend"]
# Out:
# C:\Users\TianM\AppData\Local\Temp\ipykernel_4080\1619621619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos["Factory POS/Trade Spend"] = df_pos["Factory POS"]/df_pos["Trade Spend"]

# %%
df_pos
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# 9    2021     2  2021-01-11  Need State 5   601776.75         1049389.50
# 14   2021     3  2021-01-18  Need State 5   670983.00         1050538.50
# 19   2021     4  2021-01-25  Need State 5   624003.00         1042530.00
# 24   2021     5  2021-02-01  Need State 5   602572.50         1041183.75
# ..    ...   ...         ...           ...         ...                ...
# 704  2023    37  2023-09-11  Need State 5  1501643.25         1794207.00
# 709  2023    38  2023-09-18  Need State 5  1476577.50         1657944.00
# 714  2023    39  2023-09-25  Need State 5  1426885.50         1442409.75
# 719  2023    40  2023-10-02  Need State 5  1386183.75         1373699.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)      Sales  Trade Spend  \
# ...

# %%
sns.lineplot(data = df_pos, x='Date', y='Factory POS/Trade Spend')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
df_pos.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\Trade Spend POS TEST.csv', index=False)

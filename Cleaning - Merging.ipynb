# %%
# import pandas
import pandas as pd

# %%
# Load all cleaned csv data

df_dc = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\Customer DC Inventory.csv')
df_factory = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\Factory POS $.csv')
df_ecomm = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\Total Ecomm POS (Factory $).csv')
df_sales = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\Total Sales.csv')
df_trade = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\Total Trade Spend.csv')

# %%
df_dc
# Out:
#      Unnamed: 0  Year  Week        Date   Need States   Dc Amount  \
# 0             0  2021     1  2021-01-04  Need State 1  1445929.50
# 1             1  2021     1  2021-01-04  Need State 2  2405549.25
# 2             2  2021     1  2021-01-04  Need State 3  1618319.25
# 3             3  2021     1  2021-01-04  Need State 4  1271980.50
# 4             4  2021     1  2021-01-04  Need State 5   601577.25
# ..          ...   ...   ...         ...           ...         ...
# 865         865  2023    41  2023-10-09  Need State 2  1084670.25
# 866         866  2023    41  2023-10-09  Need State 3  1180187.25
# 867         867  2023    41  2023-10-09  Need State 4   737967.00
# 868         868  2023    41  2023-10-09  Need State 5  1352883.75
# 869         869  2023    41  2023-10-09  Need State 6   756188.25
#
#      Store Amt On Hand
# 0           3667244.25
# 1           2784957.75
# 2           3838764.00
# 3           1893348.00
# 4           1055337.75
# ..                 ...
# ...

# %%
df_factory
# Out:
#      Unnamed: 0  Year  Week        Date   Need States  Factory POS
# 0             0  2021     1  2021-01-04  Need State 1    317435.25
# 1             1  2021     1  2021-01-04  Need State 2    410931.00
# 2             2  2021     1  2021-01-04  Need State 3    355992.75
# 3             3  2021     1  2021-01-04  Need State 4    451255.50
# 4             4  2021     1  2021-01-04  Need State 5     15795.00
# ..          ...   ...   ...         ...           ...          ...
# 865         865  2023    41  2023-10-09  Need State 2    351225.75
# 866         866  2023    41  2023-10-09  Need State 3    271016.25
# 867         867  2023    41  2023-10-09  Need State 4    418831.50
# 868         868  2023    41  2023-10-09  Need State 5     36111.00
# 869         869  2023    41  2023-10-09  Need State 6    527268.00
#
# [870 rows x 6 columns]

# %%
df_ecomm
# Out:
#      Unnamed: 0  Year  Week        Date   Need States  Ecomm POS (Factory $)
# 0             0  2021     1  2021-01-04  Need State 1                3684.75
# 1             1  2021     1  2021-01-04  Need State 2               11283.00
# 2             2  2021     1  2021-01-04  Need State 3               11958.75
# 3             3  2021     1  2021-01-04  Need State 4               14755.50
# 4             4  2021     1  2021-01-04  Need State 5                 448.50
# ..          ...   ...   ...         ...           ...                    ...
# 865         865  2023    41  2023-10-09  Need State 2                6606.75
# 866         866  2023    41  2023-10-09  Need State 3                5431.50
# 867         867  2023    41  2023-10-09  Need State 4                8591.25
# 868         868  2023    41  2023-10-09  Need State 5                 928.50
# 869         869  2023    41  2023-10-09  Need State 6                6583.50
#
# [870 rows x 6 columns]

# %%
df_sales
# Out:
#      Unnamed: 0  Year  Week        Date   Need States      Sales
# 0             0  2021     1  2021-01-04  Need State 1  132818.25
# 1             1  2021     1  2021-01-04  Need State 2  251858.25
# 2             2  2021     1  2021-01-04  Need State 3  209473.50
# 3             3  2021     1  2021-01-04  Need State 4  373678.50
# 4             4  2021     1  2021-01-04  Need State 5  246819.75
# ..          ...   ...   ...         ...           ...        ...
# 730         730  2023    43  2023-10-23  Need State 1  196313.25
# 731         731  2023    43  2023-10-23  Need State 2   17168.25
# 732         732  2023    43  2023-10-23  Need State 3   19847.25
# 733         733  2023    43  2023-10-23  Need State 4   22635.00
# 734         734  2023    43  2023-10-23  Need State 5   73047.00
#
# [735 rows x 6 columns]

# %%
df_trade
# Out:
#      Unnamed: 0  Year  Week        Date   Need States  Trade Spend
# 0             0  2021     1  2021-01-04  Need State 1         5552
# 1             1  2021     1  2021-01-04  Need State 2        14264
# 2             2  2021     1  2021-01-04  Need State 3         1563
# 3             3  2021     1  2021-01-04  Need State 4        18716
# 4             4  2021     1  2021-01-04  Need State 5         5075
# ..          ...   ...   ...         ...           ...          ...
# 740         740  2023    50  2023-12-11  Need State 1        15705
# 741         741  2023    50  2023-12-11  Need State 2         4216
# 742         742  2023    50  2023-12-11  Need State 3         6644
# 743         743  2023    50  2023-12-11  Need State 4         2088
# 744         744  2023    50  2023-12-11  Need State 5          538
#
# [745 rows x 6 columns]

# %%
# df_sales and df_trade cover slightly different data from the other files, so we'll remove some rows to make them the same

# %%
# remove Need State 6 from all datasets that have it
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
# https://saturncloud.io/blog/how-to-remove-rows-with-specific-values-in-pandas-dataframe/#:~:text=Another%20method%20to%20remove%20rows,value%20we%20want%20to%20remove.
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.index.html

df_dc = df_dc.drop(df_dc[df_dc['Need States'] == 'Need State 6'].index)
df_factory = df_factory.drop(df_factory[df_factory['Need States'] == 'Need State 6'].index)
df_ecomm = df_ecomm.drop(df_ecomm[df_ecomm['Need States'] == 'Need State 6'].index)

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html

df_dc = df_dc.reset_index()
df_factory = df_factory.reset_index()
df_ecomm = df_ecomm.reset_index()

# %%
df_dc
# Out:
#      index  Unnamed: 0  Year  Week        Date   Need States   Dc Amount  \
# 0        0           0  2021     1  2021-01-04  Need State 1  1445929.50
# 1        1           1  2021     1  2021-01-04  Need State 2  2405549.25
# 2        2           2  2021     1  2021-01-04  Need State 3  1618319.25
# 3        3           3  2021     1  2021-01-04  Need State 4  1271980.50
# 4        4           4  2021     1  2021-01-04  Need State 5   601577.25
# ..     ...         ...   ...   ...         ...           ...         ...
# 720    864         864  2023    41  2023-10-09  Need State 1  2191140.00
# 721    865         865  2023    41  2023-10-09  Need State 2  1084670.25
# 722    866         866  2023    41  2023-10-09  Need State 3  1180187.25
# 723    867         867  2023    41  2023-10-09  Need State 4   737967.00
# 724    868         868  2023    41  2023-10-09  Need State 5  1352883.75
#
#      Store Amt On Hand
# 0           3667244.25
# 1           2784957.75
# ...

# %%
df_factory
# Out:
#      index  Unnamed: 0  Year  Week        Date   Need States  Factory POS
# 0        0           0  2021     1  2021-01-04  Need State 1    317435.25
# 1        1           1  2021     1  2021-01-04  Need State 2    410931.00
# 2        2           2  2021     1  2021-01-04  Need State 3    355992.75
# 3        3           3  2021     1  2021-01-04  Need State 4    451255.50
# 4        4           4  2021     1  2021-01-04  Need State 5     15795.00
# ..     ...         ...   ...   ...         ...           ...          ...
# 720    864         864  2023    41  2023-10-09  Need State 1    338671.50
# 721    865         865  2023    41  2023-10-09  Need State 2    351225.75
# 722    866         866  2023    41  2023-10-09  Need State 3    271016.25
# 723    867         867  2023    41  2023-10-09  Need State 4    418831.50
# 724    868         868  2023    41  2023-10-09  Need State 5     36111.00
#
# [725 rows x 7 columns]

# %%
df_ecomm
# Out:
#      index  Unnamed: 0  Year  Week        Date   Need States  \
# 0        0           0  2021     1  2021-01-04  Need State 1
# 1        1           1  2021     1  2021-01-04  Need State 2
# 2        2           2  2021     1  2021-01-04  Need State 3
# 3        3           3  2021     1  2021-01-04  Need State 4
# 4        4           4  2021     1  2021-01-04  Need State 5
# ..     ...         ...   ...   ...         ...           ...
# 720    864         864  2023    41  2023-10-09  Need State 1
# 721    865         865  2023    41  2023-10-09  Need State 2
# 722    866         866  2023    41  2023-10-09  Need State 3
# 723    867         867  2023    41  2023-10-09  Need State 4
# 724    868         868  2023    41  2023-10-09  Need State 5
#
#      Ecomm POS (Factory $)
# 0                  3684.75
# 1                 11283.00
# 2                 11958.75
# 3                 14755.50
# 4                   448.50
# ..                     ...
# 720                2469.00
# ...

# %%
# remove the extra weeks covered in 2023 in df_sales and df_trade
# https://www.w3schools.com/python/ref_func_range.asp

for index in range(725, 735):
    df_sales.drop([index], inplace=True)

# %%
for index in range(725, 745):
    df_trade.drop([index], inplace=True)

# %%
df_sales
# Out:
#      Unnamed: 0  Year  Week        Date   Need States      Sales
# 0             0  2021     1  2021-01-04  Need State 1  132818.25
# 1             1  2021     1  2021-01-04  Need State 2  251858.25
# 2             2  2021     1  2021-01-04  Need State 3  209473.50
# 3             3  2021     1  2021-01-04  Need State 4  373678.50
# 4             4  2021     1  2021-01-04  Need State 5  246819.75
# ..          ...   ...   ...         ...           ...        ...
# 720         720  2023    41  2023-10-09  Need State 1  550887.00
# 721         721  2023    41  2023-10-09  Need State 2  221686.50
# 722         722  2023    41  2023-10-09  Need State 3  121078.50
# 723         723  2023    41  2023-10-09  Need State 4  240855.75
# 724         724  2023    41  2023-10-09  Need State 5  600489.00
#
# [725 rows x 6 columns]

# %%
df_trade
# Out:
#      Unnamed: 0  Year  Week        Date   Need States  Trade Spend
# 0             0  2021     1  2021-01-04  Need State 1         5552
# 1             1  2021     1  2021-01-04  Need State 2        14264
# 2             2  2021     1  2021-01-04  Need State 3         1563
# 3             3  2021     1  2021-01-04  Need State 4        18716
# 4             4  2021     1  2021-01-04  Need State 5         5075
# ..          ...   ...   ...         ...           ...          ...
# 720         720  2023    41  2023-10-09  Need State 1         2918
# 721         721  2023    41  2023-10-09  Need State 2         2361
# 722         722  2023    41  2023-10-09  Need State 3        15546
# 723         723  2023    41  2023-10-09  Need State 4         7217
# 724         724  2023    41  2023-10-09  Need State 5         9652
#
# [725 rows x 6 columns]

# %%
# remove unnecessary columns

df_dc = df_dc.drop(['index', 'Unnamed: 0'], axis=1)
df_factory = df_factory.drop(['index', 'Unnamed: 0'], axis=1)
df_ecomm = df_ecomm.drop(['index', 'Unnamed: 0'], axis=1)

# %%
df_sales = df_sales.drop(['Unnamed: 0'], axis=1)
df_trade = df_trade.drop(['Unnamed: 0'], axis=1)

# %%
df_dc
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand
# 0    2021     1  2021-01-04  Need State 1  1445929.50         3667244.25
# 1    2021     1  2021-01-04  Need State 2  2405549.25         2784957.75
# 2    2021     1  2021-01-04  Need State 3  1618319.25         3838764.00
# 3    2021     1  2021-01-04  Need State 4  1271980.50         1893348.00
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# ..    ...   ...         ...           ...         ...                ...
# 720  2023    41  2023-10-09  Need State 1  2191140.00         5903348.25
# 721  2023    41  2023-10-09  Need State 2  1084670.25         4117591.50
# 722  2023    41  2023-10-09  Need State 3  1180187.25         4954347.00
# 723  2023    41  2023-10-09  Need State 4   737967.00         1948076.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
# [725 rows x 6 columns]

# %%
df_factory
# Out:
#      Year  Week        Date   Need States  Factory POS
# 0    2021     1  2021-01-04  Need State 1    317435.25
# 1    2021     1  2021-01-04  Need State 2    410931.00
# 2    2021     1  2021-01-04  Need State 3    355992.75
# 3    2021     1  2021-01-04  Need State 4    451255.50
# 4    2021     1  2021-01-04  Need State 5     15795.00
# ..    ...   ...         ...           ...          ...
# 720  2023    41  2023-10-09  Need State 1    338671.50
# 721  2023    41  2023-10-09  Need State 2    351225.75
# 722  2023    41  2023-10-09  Need State 3    271016.25
# 723  2023    41  2023-10-09  Need State 4    418831.50
# 724  2023    41  2023-10-09  Need State 5     36111.00
#
# [725 rows x 5 columns]

# %%
df_ecomm
# Out:
#      Year  Week        Date   Need States  Ecomm POS (Factory $)
# 0    2021     1  2021-01-04  Need State 1                3684.75
# 1    2021     1  2021-01-04  Need State 2               11283.00
# 2    2021     1  2021-01-04  Need State 3               11958.75
# 3    2021     1  2021-01-04  Need State 4               14755.50
# 4    2021     1  2021-01-04  Need State 5                 448.50
# ..    ...   ...         ...           ...                    ...
# 720  2023    41  2023-10-09  Need State 1                2469.00
# 721  2023    41  2023-10-09  Need State 2                6606.75
# 722  2023    41  2023-10-09  Need State 3                5431.50
# 723  2023    41  2023-10-09  Need State 4                8591.25
# 724  2023    41  2023-10-09  Need State 5                 928.50
#
# [725 rows x 5 columns]

# %%
df_sales
# Out:
#      Year  Week        Date   Need States      Sales
# 0    2021     1  2021-01-04  Need State 1  132818.25
# 1    2021     1  2021-01-04  Need State 2  251858.25
# 2    2021     1  2021-01-04  Need State 3  209473.50
# 3    2021     1  2021-01-04  Need State 4  373678.50
# 4    2021     1  2021-01-04  Need State 5  246819.75
# ..    ...   ...         ...           ...        ...
# 720  2023    41  2023-10-09  Need State 1  550887.00
# 721  2023    41  2023-10-09  Need State 2  221686.50
# 722  2023    41  2023-10-09  Need State 3  121078.50
# 723  2023    41  2023-10-09  Need State 4  240855.75
# 724  2023    41  2023-10-09  Need State 5  600489.00
#
# [725 rows x 5 columns]

# %%
df_trade
# Out:
#      Year  Week        Date   Need States  Trade Spend
# 0    2021     1  2021-01-04  Need State 1         5552
# 1    2021     1  2021-01-04  Need State 2        14264
# 2    2021     1  2021-01-04  Need State 3         1563
# 3    2021     1  2021-01-04  Need State 4        18716
# 4    2021     1  2021-01-04  Need State 5         5075
# ..    ...   ...         ...           ...          ...
# 720  2023    41  2023-10-09  Need State 1         2918
# 721  2023    41  2023-10-09  Need State 2         2361
# 722  2023    41  2023-10-09  Need State 3        15546
# 723  2023    41  2023-10-09  Need State 4         7217
# 724  2023    41  2023-10-09  Need State 5         9652
#
# [725 rows x 5 columns]

# %%
# merge datasets
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html#database-style-dataframe-or-named-series-joining-merging
# https://realpython.com/pandas-merge-join-and-concat/#:~:text=merge()%20for%20combining%20data,DataFrames%20across%20rows%20or%20columns

df = pd.merge(df_dc, df_factory)

# %%
df
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 0    2021     1  2021-01-04  Need State 1  1445929.50         3667244.25
# 1    2021     1  2021-01-04  Need State 2  2405549.25         2784957.75
# 2    2021     1  2021-01-04  Need State 3  1618319.25         3838764.00
# 3    2021     1  2021-01-04  Need State 4  1271980.50         1893348.00
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# ..    ...   ...         ...           ...         ...                ...
# 720  2023    41  2023-10-09  Need State 1  2191140.00         5903348.25
# 721  2023    41  2023-10-09  Need State 2  1084670.25         4117591.50
# 722  2023    41  2023-10-09  Need State 3  1180187.25         4954347.00
# 723  2023    41  2023-10-09  Need State 4   737967.00         1948076.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS
# 0      317435.25
# 1      410931.00
# 2      355992.75
# 3      451255.50
# ...

# %%
df = pd.merge(df, df_ecomm)

# %%
df
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 0    2021     1  2021-01-04  Need State 1  1445929.50         3667244.25
# 1    2021     1  2021-01-04  Need State 2  2405549.25         2784957.75
# 2    2021     1  2021-01-04  Need State 3  1618319.25         3838764.00
# 3    2021     1  2021-01-04  Need State 4  1271980.50         1893348.00
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# ..    ...   ...         ...           ...         ...                ...
# 720  2023    41  2023-10-09  Need State 1  2191140.00         5903348.25
# 721  2023    41  2023-10-09  Need State 2  1084670.25         4117591.50
# 722  2023    41  2023-10-09  Need State 3  1180187.25         4954347.00
# 723  2023    41  2023-10-09  Need State 4   737967.00         1948076.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)
# 0      317435.25                3684.75
# ...

# %%
df = pd.merge(df, df_sales)

# %%
df
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 0    2021     1  2021-01-04  Need State 1  1445929.50         3667244.25
# 1    2021     1  2021-01-04  Need State 2  2405549.25         2784957.75
# 2    2021     1  2021-01-04  Need State 3  1618319.25         3838764.00
# 3    2021     1  2021-01-04  Need State 4  1271980.50         1893348.00
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# ..    ...   ...         ...           ...         ...                ...
# 720  2023    41  2023-10-09  Need State 1  2191140.00         5903348.25
# 721  2023    41  2023-10-09  Need State 2  1084670.25         4117591.50
# 722  2023    41  2023-10-09  Need State 3  1180187.25         4954347.00
# 723  2023    41  2023-10-09  Need State 4   737967.00         1948076.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)      Sales
# ...

# %%
df = pd.merge(df, df_trade)

# %%
# final merged dataframe

df
# Out:
#      Year  Week        Date   Need States   Dc Amount  Store Amt On Hand  \
# 0    2021     1  2021-01-04  Need State 1  1445929.50         3667244.25
# 1    2021     1  2021-01-04  Need State 2  2405549.25         2784957.75
# 2    2021     1  2021-01-04  Need State 3  1618319.25         3838764.00
# 3    2021     1  2021-01-04  Need State 4  1271980.50         1893348.00
# 4    2021     1  2021-01-04  Need State 5   601577.25         1055337.75
# ..    ...   ...         ...           ...         ...                ...
# 720  2023    41  2023-10-09  Need State 1  2191140.00         5903348.25
# 721  2023    41  2023-10-09  Need State 2  1084670.25         4117591.50
# 722  2023    41  2023-10-09  Need State 3  1180187.25         4954347.00
# 723  2023    41  2023-10-09  Need State 4   737967.00         1948076.25
# 724  2023    41  2023-10-09  Need State 5  1352883.75         1329480.75
#
#      Factory POS  Ecomm POS (Factory $)      Sales  Trade Spend
# ...

# %%
import seaborn as sns

# %%
# test graph: does sales depend on trade spend?
# https://seaborn.pydata.org/examples/different_scatter_variables.html

sns.scatterplot(data=df, x='Trade Spend', y='Sales', hue='Year')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Trade Spend', ylabel='Sales'>

# %%
# write the dataframe to a csv file
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html
df.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\All Merged.csv', index=False)

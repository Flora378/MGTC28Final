# %%
# This is an example of how I would clean and reorganize the data.  First, let's import the library 'Pandas'
import pandas as pd

# %%
# Loading the CSV data.  Noticed that I decleard row 0 and row 1 as header.  The data actually begins in row 2.
# By doing this, I created a multi index. See documentation: https://pandas.pydata.org/docs/user_guide/advanced.html
df = pd.read_csv('/Users/katherinefeng/Desktop/kenvue_data/Factory POS $ - UTSC Lecture.csv', header=[0,1])

# %%
# Let's see what it looks like.  Noticed that there are 2 header rows.
df
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Fiscal Year
#             Need State        Fiscal Week        2021       2022       2023
# 0         Need State 1                  1   317435.25  348637.50  372921.75
# 1         Need State 1                  2   309234.75  343799.25  357329.25
# 2         Need State 1                  3   331149.00  346592.25  352571.25
# 3         Need State 1                  4   291885.00  344795.25  331310.25
# 4         Need State 1                  5   308238.00  338146.50  383741.25
# ..                 ...                ...         ...        ...        ...
# 307       Need State 6                 48   482283.00  585123.75       0.00
# 308       Need State 6                 49   411926.25  540969.00       0.00
# 309       Need State 6                 50   428814.75  584413.50       0.00
# 310       Need State 6                 51   470064.75  581396.25       0.00
# 311       Need State 6                 52   373771.50  552392.25       0.00
#
# [312 rows x 5 columns]

# %%
# This is called multi index.  See documentation: https://pandas.pydata.org/docs/user_guide/advanced.html
df.columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',  'Need State'),
#             ('Unnamed: 1_level_0', 'Fiscal Week'),
#             (       'Fiscal Year',        '2021'),
#             (       'Fiscal Year',        '2022'),
#             (       'Fiscal Year',        '2023')],
#            )

# %%
# Instead of having numbers in row index, I am going to set customized index levels
df = df.set_index([('Unnamed: 0_level_0', 'Need State'), ('Unnamed: 1_level_0', 'Fiscal Week')])

# %%
# Swapping Rows <-> Columns
df = df.T

# %%
# Let's take a look..getting a bit more organized now.
df
# Out:
# ('Unnamed: 0_level_0', 'Need State')  Need State 1                        \
# ('Unnamed: 1_level_0', 'Fiscal Week')           1          2          3
# Fiscal Year 2021                         317435.25  309234.75  331149.00
#             2022                         348637.50  343799.25  346592.25
#             2023                         372921.75  357329.25  352571.25
#
# ('Unnamed: 0_level_0', 'Need State')                                    \
# ('Unnamed: 1_level_0', 'Fiscal Week')         4          5          6
# Fiscal Year 2021                       291885.00  308238.00  267614.25
#             2022                       344795.25  338146.50  307596.75
#             2023                       331310.25  383741.25  307953.75
#
# ('Unnamed: 0_level_0', 'Need State')                                    \
# ('Unnamed: 1_level_0', 'Fiscal Week')         7          8          9
# Fiscal Year 2021                       277594.50  288708.00  305426.25
#             2022                       302883.00  343384.50  341754.00
#             2023                       318695.25  324699.75  316498.50
#
# ('Unnamed: 0_level_0', 'Need State')              ... Need State 6             \
# ('Unnamed: 1_level_0', 'Fiscal Week')         10  ...           43         44
# Fiscal Year 2021                       366468.75  ...    526055.25  432303.75
#             2022                       396704.25  ...    485091.00  409923.75
#             2023                       338994.75  ...         0.00       0.00
#
# ('Unnamed: 0_level_0', 'Need State')                                    \
# ('Unnamed: 1_level_0', 'Fiscal Week')         45         46         47
# Fiscal Year 2021                       475594.50  402365.25  457254.75
#             2022                       448538.25  359235.75  524727.75
#             2023                            0.00       0.00       0.00
#
# ('Unnamed: 0_level_0', 'Need State')                                    \
# ('Unnamed: 1_level_0', 'Fiscal Week')         48         49         50
# Fiscal Year 2021                       482283.00  411926.25  428814.75
#             2022                       585123.75  540969.00  584413.50
#             2023                            0.00       0.00       0.00
#
# ('Unnamed: 0_level_0', 'Need State')
# ('Unnamed: 1_level_0', 'Fiscal Week')         51         52
# Fiscal Year 2021                       470064.75  373771.50
#             2022                       581396.25  552392.25
#             2023                            0.00       0.00
#
# [3 rows x 312 columns]

# %%
# I use a Pandas stack function here to stack all the need states in one column.  
# That way my dataframe is long instead of wide.
# See stack function here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html
df = df.stack(1)

# %%
# Can you see what I did so far?
df
# Out:
# ('Unnamed: 0_level_0', 'Need State')                Need State 1  \
#                  (Unnamed: 1_level_0, Fiscal Week)
# Fiscal Year 2021 1                                     317435.25
#                  2                                     309234.75
#                  3                                     331149.00
#                  4                                     291885.00
#                  5                                     308238.00
# ...                                                          ...
#             2023 48                                         0.00
#                  49                                         0.00
#                  50                                         0.00
#                  51                                         0.00
#                  52                                         0.00
#
# ('Unnamed: 0_level_0', 'Need State')                Need State 2  \
#                  (Unnamed: 1_level_0, Fiscal Week)
# Fiscal Year 2021 1                                      410931.0
#                  2                                      447469.5
#                  3                                      471435.0
#                  4                                      427167.0
#                  5                                      529465.5
# ...                                                          ...
#             2023 48                                          0.0
#                  49                                          0.0
#                  50                                          0.0
#                  51                                          0.0
#                  52                                          0.0
#
# ('Unnamed: 0_level_0', 'Need State')                Need State 3  \
#                  (Unnamed: 1_level_0, Fiscal Week)
# Fiscal Year 2021 1                                     355992.75
#                  2                                     432966.00
#                  3                                     325530.00
#                  4                                     409405.50
#                  5                                     313095.75
# ...                                                          ...
#             2023 48                                         0.00
#                  49                                         0.00
#                  50                                         0.00
#                  51                                         0.00
#                  52                                         0.00
#
# ('Unnamed: 0_level_0', 'Need State')                Need State 4  \
#                  (Unnamed: 1_level_0, Fiscal Week)
# Fiscal Year 2021 1                                     451255.50
#                  2                                     472152.75
#                  3                                     465115.50
#                  4                                     401831.25
#                  5                                     501825.75
# ...                                                          ...
#             2023 48                                         0.00
#                  49                                         0.00
#                  50                                         0.00
#                  51                                         0.00
#                  52                                         0.00
#
# ('Unnamed: 0_level_0', 'Need State')                Need State 5  Need State 6
#                  (Unnamed: 1_level_0, Fiscal Week)
# Fiscal Year 2021 1                                      15795.00     457623.75
#                  2                                      11154.75     452605.50
#                  3                                      10549.50     519924.75
#                  4                                      10443.00     452333.25
#                  5                                      12430.50     498557.25
# ...                                                          ...           ...
#             2023 48                                         0.00          0.00
#                  49                                         0.00          0.00
#                  50                                         0.00          0.00
#                  51                                         0.00          0.00
#                  52                                         0.00          0.00
#
# [156 rows x 6 columns]

# %%
# Now I will reset the index so it will go back to numbers as row index
df= df.reset_index()

# %%
df
# Out:
# ('Unnamed: 0_level_0', 'Need State')      level_0 level_1  \
# 0                                     Fiscal Year    2021
# 1                                     Fiscal Year    2021
# 2                                     Fiscal Year    2021
# 3                                     Fiscal Year    2021
# 4                                     Fiscal Year    2021
# ..                                            ...     ...
# 151                                   Fiscal Year    2023
# 152                                   Fiscal Year    2023
# 153                                   Fiscal Year    2023
# 154                                   Fiscal Year    2023
# 155                                   Fiscal Year    2023
#
# ('Unnamed: 0_level_0', 'Need State')  (Unnamed: 1_level_0, Fiscal Week)  \
# 0                                                                     1
# 1                                                                     2
# 2                                                                     3
# 3                                                                     4
# 4                                                                     5
# ..                                                                  ...
# 151                                                                  48
# 152                                                                  49
# 153                                                                  50
# 154                                                                  51
# 155                                                                  52
#
# ('Unnamed: 0_level_0', 'Need State')  Need State 1  Need State 2  \
# 0                                        317435.25      410931.0
# 1                                        309234.75      447469.5
# 2                                        331149.00      471435.0
# 3                                        291885.00      427167.0
# 4                                        308238.00      529465.5
# ..                                             ...           ...
# 151                                           0.00           0.0
# 152                                           0.00           0.0
# 153                                           0.00           0.0
# 154                                           0.00           0.0
# 155                                           0.00           0.0
#
# ('Unnamed: 0_level_0', 'Need State')  Need State 3  Need State 4  \
# 0                                        355992.75     451255.50
# 1                                        432966.00     472152.75
# 2                                        325530.00     465115.50
# 3                                        409405.50     401831.25
# 4                                        313095.75     501825.75
# ..                                             ...           ...
# 151                                           0.00          0.00
# 152                                           0.00          0.00
# 153                                           0.00          0.00
# 154                                           0.00          0.00
# 155                                           0.00          0.00
#
# ('Unnamed: 0_level_0', 'Need State')  Need State 5  Need State 6
# 0                                         15795.00     457623.75
# 1                                         11154.75     452605.50
# 2                                         10549.50     519924.75
# 3                                         10443.00     452333.25
# 4                                         12430.50     498557.25
# ..                                             ...           ...
# 151                                           0.00          0.00
# 152                                           0.00          0.00
# 153                                           0.00          0.00
# 154                                           0.00          0.00
# 155                                           0.00          0.00
#
# [156 rows x 9 columns]

# %%
# Let's rename the columns
df = df.rename_axis(None, axis=1)
df = df.rename(columns={df.columns[0]: "year", df.columns[1]: "Year", df.columns[2]: "Week"})

# %%
df
# Out:
#             year  Year  Week  Need State 1  Need State 2  Need State 3  \
# 0    Fiscal Year  2021     1     317435.25      410931.0     355992.75
# 1    Fiscal Year  2021     2     309234.75      447469.5     432966.00
# 2    Fiscal Year  2021     3     331149.00      471435.0     325530.00
# 3    Fiscal Year  2021     4     291885.00      427167.0     409405.50
# 4    Fiscal Year  2021     5     308238.00      529465.5     313095.75
# ..           ...   ...   ...           ...           ...           ...
# 151  Fiscal Year  2023    48          0.00           0.0          0.00
# 152  Fiscal Year  2023    49          0.00           0.0          0.00
# 153  Fiscal Year  2023    50          0.00           0.0          0.00
# 154  Fiscal Year  2023    51          0.00           0.0          0.00
# 155  Fiscal Year  2023    52          0.00           0.0          0.00
#
#      Need State 4  Need State 5  Need State 6
# 0       451255.50      15795.00     457623.75
# 1       472152.75      11154.75     452605.50
# 2       465115.50      10549.50     519924.75
# 3       401831.25      10443.00     452333.25
# 4       501825.75      12430.50     498557.25
# ..            ...           ...           ...
# 151          0.00          0.00          0.00
# 152          0.00          0.00          0.00
# 153          0.00          0.00          0.00
# 154          0.00          0.00          0.00
# 155          0.00          0.00          0.00
#
# [156 rows x 9 columns]

# %%
# Delete the first column that contains 'Fiscal Year'
df = df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#      Year  Week  Need State 1  Need State 2  Need State 3  Need State 4  \
# 0    2021     1     317435.25      410931.0     355992.75     451255.50
# 1    2021     2     309234.75      447469.5     432966.00     472152.75
# 2    2021     3     331149.00      471435.0     325530.00     465115.50
# 3    2021     4     291885.00      427167.0     409405.50     401831.25
# 4    2021     5     308238.00      529465.5     313095.75     501825.75
# ..    ...   ...           ...           ...           ...           ...
# 151  2023    48          0.00           0.0          0.00          0.00
# 152  2023    49          0.00           0.0          0.00          0.00
# 153  2023    50          0.00           0.0          0.00          0.00
# 154  2023    51          0.00           0.0          0.00          0.00
# 155  2023    52          0.00           0.0          0.00          0.00
#
#      Need State 5  Need State 6
# 0        15795.00     457623.75
# 1        11154.75     452605.50
# 2        10549.50     519924.75
# 3        10443.00     452333.25
# 4        12430.50     498557.25
# ..            ...           ...
# 151          0.00          0.00
# 152          0.00          0.00
# 153          0.00          0.00
# 154          0.00          0.00
# 155          0.00          0.00
#
# [156 rows x 8 columns]

# %%
import seaborn as sns

# %%
import pandas as pd
import seaborn as sns

# %%
# upload data
df0 = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\result.csv')
df1 = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\result (1).csv')
df2 = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\result (2).csv')
df3 = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\result (3).csv')
df4 = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\result (4).csv')

# %%
df0
# Out:
#             Y       X  uv_index_hourly_average  \
# 0       53.55 -114.11                 0.245562
# 1       53.55 -114.11                 0.024375
# 2       53.55 -114.11                 0.089713
# 3       53.55 -114.11                 0.118058
# 4       53.55 -114.11                 0.196383
# ...       ...     ...                      ...
# 199995  79.99  -85.93                 0.287040
# 199996  82.50  -62.32                 0.114320
# 199997  82.50  -62.32                 0.012056
# 199998  82.50  -62.32                 0.005240
# 199999  82.50  -62.32                 0.041973
#
#                                                       url   dataset  \
# 0       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 1       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 2       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 3       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# ...

# %%
df1
# Out:
#             Y      X  uv_index_hourly_average  \
# 0       82.50 -62.32                 0.052240
# 1       79.99 -85.93                 0.100800
# 2       82.50 -62.32                 0.341533
# 3       79.99 -85.93                 0.444060
# 4       82.50 -62.32                 0.018210
# ...       ...    ...                      ...
# 199995  58.75 -94.07                 3.047730
# 199996  45.48 -73.75                 0.905747
# 199997  74.72 -94.98                 0.101840
# 199998  58.75 -94.07                 0.191040
# 199999  45.48 -73.75                 2.095773
#
#                                                       url   dataset  \
# 0       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 1       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 2       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 3       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# ...

# %%
df2
# Out:
#             Y       X  uv_index_hourly_average  \
# 0       74.72  -94.98                 0.303200
# 1       45.48  -73.75                 5.026387
# 2       74.72  -94.98                 0.010840
# 3       45.48  -73.75                 6.222900
# 4       74.72  -94.98                 0.002360
# ...       ...     ...                      ...
# 199995  52.11 -106.71                 0.494240
# 199996  48.78 -123.13                 2.664533
# 199997  52.11 -106.71                 3.094800
# 199998  48.78 -123.13                 1.151440
# 199999  52.11 -106.71                 4.261800
#
#                                                       url   dataset  \
# 0       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 1       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 2       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 3       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# ...

# %%
df3
# Out:
#             Y       X  uv_index_hourly_average  \
# 0       48.78 -123.13                 1.289373
# 1       52.11 -106.71                 0.590440
# 2       48.78 -123.13                 1.700253
# 3       44.66  -63.57                 1.000220
# 4       48.78 -123.13                 0.227107
# ...       ...     ...                      ...
# 199995  48.78 -123.13                 0.831960
# 199996  52.11 -106.71                 0.289440
# 199997  48.78 -123.13                 2.565467
# 199998  52.11 -106.71                 2.127760
# 199999  48.78 -123.13                 0.363440
#
#                                                       url   dataset  \
# 0       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 1       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 2       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 3       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# ...

# %%
df4
# Out:
#             Y       X  uv_index_hourly_average  \
# 0       52.11 -106.71                  0.63548
# 1       48.78 -123.13                  3.78292
# 2       52.11 -106.71                  3.58968
# 3       48.78 -123.13                  1.79284
# 4       50.21 -104.71                  2.13626
# ...       ...     ...                      ...
# 103675  43.78  -79.47                  0.07484
# 103676  43.78  -79.47                  2.67816
# 103677  43.78  -79.47                  1.27512
# 103678  43.78  -79.47                  0.63188
# 103679  43.78  -79.47                  0.40114
#
#                                                       url   dataset  \
# 0       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 1       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 2       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# 3       https://woudc.org/archive/Archive-NewFormat/Sp...  Spectral
# ...

# %%
# check if everything is the right type
df0.dtypes
# Out:
# Y                          float64
# X                          float64
# uv_index_hourly_average    float64
# url                         object
# dataset                     object
# instance_datetime           object
# platform_id                  int64
# platform_name               object
# country                     object
# gaw_id                      object
# instrument_name             object
# instrument_model            object
# instrument_number            int64
# uv_index_qa                 object
# instance_hour                int64
# platform_type               object
# data_payload_id              int64
# latest_observation           int64
# uv_index_daily_max         float64
# agency                      object
# dtype: object

# %%
df1.dtypes
# Out:
# Y                          float64
# X                          float64
# uv_index_hourly_average    float64
# url                         object
# dataset                     object
# instance_datetime           object
# platform_id                  int64
# platform_name               object
# country                     object
# gaw_id                      object
# instrument_name             object
# instrument_model            object
# instrument_number            int64
# uv_index_qa                 object
# instance_hour                int64
# platform_type               object
# data_payload_id              int64
# latest_observation           int64
# uv_index_daily_max         float64
# agency                      object
# dtype: object

# %%
# combine dataframes
# https://pandas.pydata.org/docs/user_guide/merging.html

cat_list = [df0, df1, df2, df3, df4]

# %%
df = pd.concat(cat_list, ignore_index=True)

# %%
df
# Out:
#             Y       X  uv_index_hourly_average  \
# 0       53.55 -114.11                 0.245562
# 1       53.55 -114.11                 0.024375
# 2       53.55 -114.11                 0.089713
# 3       53.55 -114.11                 0.118058
# 4       53.55 -114.11                 0.196383
# ...       ...     ...                      ...
# 903675  43.78  -79.47                 0.074840
# 903676  43.78  -79.47                 2.678160
# 903677  43.78  -79.47                 1.275120
# 903678  43.78  -79.47                 0.631880
# 903679  43.78  -79.47                 0.401140
#
#                                                       url   dataset  \
# 0       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 1       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 2       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 3       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# ...

# %%
# save to computer -- import to Tableau for graphing
df.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\UV Index Data.csv', index=False)

# %% [markdown]
# # Extra:

# %%
sns.lineplot(data = df, x='instance_datetime', y='uv_index_hourly_average')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
df.describe()
# Out:
#                    Y              X  uv_index_hourly_average    platform_id  \
# count  903680.000000  903680.000000            903680.000000  903680.000000
# mean       55.986022     -89.322794                 1.284633     159.481981
# std        13.019757      19.744200                 1.657478     133.503289
# min        43.660000    -123.130000                 0.000050      18.000000
# 25%        45.480000    -104.710000                 0.150380      24.000000
# 50%        52.110000     -94.070000                 0.585660      77.000000
# 75%        58.750000     -73.750000                 1.753280     315.000000
# max        82.500000     -60.360000                12.022600     512.000000
#
#        instrument_number  instance_hour  data_payload_id  latest_observation  \
# count      903680.000000  903680.000000     9.036800e+05       903680.000000
# mean           43.060525       7.982424     1.379455e+06            0.000021
# ...

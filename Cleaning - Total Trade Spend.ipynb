# %%
# import pandas
import pandas as pd

# %%
# load CSV data and declare row 0 as header
# https://pandas.pydata.org/docs/user_guide/advanced.html

df = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\raw\\Total Trade Spend.csv', header=[0])

# %%
df
# Out:
#      Fiscal Year  Fiscal Week  Need State 1  Need State 2  Need State 3  \
# 0           2021            1          5552         14264          1563
# 1           2021            2         18939         12329          8658
# 2           2021            3         11346          6351          4032
# 3           2021            4          4801         14715         13935
# 4           2021            5         17470         16092         13601
# ..           ...          ...           ...           ...           ...
# 144         2023           41          2918          2361         15546
# 145         2023           42         10743         15952          3993
# 146         2023           43          7823         19451         12462
# 147         2023           46         19575         14362         12145
# 148         2023           50         15705          4216          6644
#
#      Need State 4  Need State 5
# 0           18716          5075
# 1            8069         11307
# ...

# %%
df.columns
# Out:
# Index(['Fiscal Year', 'Fiscal Week', 'Need State 1', 'Need State 2',
#        'Need State 3', 'Need State 4', 'Need State 5'],
#       dtype='object')

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.melt.html
df = df.melt(id_vars=['Fiscal Year', 'Fiscal Week'])

# %%
df
# Out:
#      Fiscal Year  Fiscal Week      variable  value
# 0           2021            1  Need State 1   5552
# 1           2021            2  Need State 1  18939
# 2           2021            3  Need State 1  11346
# 3           2021            4  Need State 1   4801
# 4           2021            5  Need State 1  17470
# ..           ...          ...           ...    ...
# 740         2023           41  Need State 5   9652
# 741         2023           42  Need State 5  17320
# 742         2023           43  Need State 5   4638
# 743         2023           46  Need State 5    575
# 744         2023           50  Need State 5    538
#
# [745 rows x 4 columns]

# %%
# rename the columns
df = df.rename(columns={df.columns[0]: "Year", df.columns[1]: "Week", df.columns[2]: "Need States", df.columns[3]: "Trade Spend"})

# %%
df
# Out:
#      Year  Week   Need States  Trade Spend
# 0    2021     1  Need State 1         5552
# 1    2021     2  Need State 1        18939
# 2    2021     3  Need State 1        11346
# 3    2021     4  Need State 1         4801
# 4    2021     5  Need State 1        17470
# ..    ...   ...           ...          ...
# 740  2023    41  Need State 5         9652
# 741  2023    42  Need State 5        17320
# 742  2023    43  Need State 5         4638
# 743  2023    46  Need State 5          575
# 744  2023    50  Need State 5          538
#
# [745 rows x 4 columns]

# %%
# convert week# to an actual date for easy plotting
df['Date'] = pd.to_datetime(df["Year"].astype(str) + "-" + df["Week"].astype(str) + "-1", format='%Y-%U-%w')

# %%
df
# Out:
#      Year  Week   Need States  Trade Spend       Date
# 0    2021     1  Need State 1         5552 2021-01-04
# 1    2021     2  Need State 1        18939 2021-01-11
# 2    2021     3  Need State 1        11346 2021-01-18
# 3    2021     4  Need State 1         4801 2021-01-25
# 4    2021     5  Need State 1        17470 2021-02-01
# ..    ...   ...           ...          ...        ...
# 740  2023    41  Need State 5         9652 2023-10-09
# 741  2023    42  Need State 5        17320 2023-10-16
# 742  2023    43  Need State 5         4638 2023-10-23
# 743  2023    46  Need State 5          575 2023-11-13
# 744  2023    50  Need State 5          538 2023-12-11
#
# [745 rows x 5 columns]

# %%
import seaborn as sns

# %%
# try a couple graphs
sns.lineplot(data = df, x=df.Date, y='Trade Spend')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
sns.lineplot(data = df, x='Week', y='Trade Spend', hue='Year')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %% [markdown]
# ## Additional:

# %%
# rearrange columns
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df = df.reindex(columns=['Year','Week','Date','Need States','Trade Spend'])

# %%
df
# Out:
#      Year  Week       Date   Need States  Trade Spend
# 0    2021     1 2021-01-04  Need State 1         5552
# 1    2021     2 2021-01-11  Need State 1        18939
# 2    2021     3 2021-01-18  Need State 1        11346
# 3    2021     4 2021-01-25  Need State 1         4801
# 4    2021     5 2021-02-01  Need State 1        17470
# ..    ...   ...        ...           ...          ...
# 740  2023    41 2023-10-09  Need State 5         9652
# 741  2023    42 2023-10-16  Need State 5        17320
# 742  2023    43 2023-10-23  Need State 5         4638
# 743  2023    46 2023-11-13  Need State 5          575
# 744  2023    50 2023-12-11  Need State 5          538
#
# [745 rows x 5 columns]

# %%
# sort values so format matches other cleaned csv files
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
df = df.sort_values(by=['Year', 'Week'])

# %%
df
# Out:
#      Year  Week       Date   Need States  Trade Spend
# 0    2021     1 2021-01-04  Need State 1         5552
# 149  2021     1 2021-01-04  Need State 2        14264
# 298  2021     1 2021-01-04  Need State 3         1563
# 447  2021     1 2021-01-04  Need State 4        18716
# 596  2021     1 2021-01-04  Need State 5         5075
# ..    ...   ...        ...           ...          ...
# 148  2023    50 2023-12-11  Need State 1        15705
# 297  2023    50 2023-12-11  Need State 2         4216
# 446  2023    50 2023-12-11  Need State 3         6644
# 595  2023    50 2023-12-11  Need State 4         2088
# 744  2023    50 2023-12-11  Need State 5          538
#
# [745 rows x 5 columns]

# %%
# reset index numbers
df = df.reset_index(drop=True)

# %%
df
# Out:
#      Year  Week       Date   Need States  Trade Spend
# 0    2021     1 2021-01-04  Need State 1         5552
# 1    2021     1 2021-01-04  Need State 2        14264
# 2    2021     1 2021-01-04  Need State 3         1563
# 3    2021     1 2021-01-04  Need State 4        18716
# 4    2021     1 2021-01-04  Need State 5         5075
# ..    ...   ...        ...           ...          ...
# 740  2023    50 2023-12-11  Need State 1        15705
# 741  2023    50 2023-12-11  Need State 2         4216
# 742  2023    50 2023-12-11  Need State 3         6644
# 743  2023    50 2023-12-11  Need State 4         2088
# 744  2023    50 2023-12-11  Need State 5          538
#
# [745 rows x 5 columns]

# %%
# replace instances of 0 with NaN
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.replace.html
# https://stackoverflow.com/questions/34794067/how-to-set-a-cell-to-nan-in-a-pandas-dataframe
df = df.replace(to_replace=0, value=pd.NA)

# %%
df
# Out:
#      Year  Week       Date   Need States  Trade Spend
# 0    2021     1 2021-01-04  Need State 1         5552
# 1    2021     1 2021-01-04  Need State 2        14264
# 2    2021     1 2021-01-04  Need State 3         1563
# 3    2021     1 2021-01-04  Need State 4        18716
# 4    2021     1 2021-01-04  Need State 5         5075
# ..    ...   ...        ...           ...          ...
# 740  2023    50 2023-12-11  Need State 1        15705
# 741  2023    50 2023-12-11  Need State 2         4216
# 742  2023    50 2023-12-11  Need State 3         6644
# 743  2023    50 2023-12-11  Need State 4         2088
# 744  2023    50 2023-12-11  Need State 5          538
#
# [745 rows x 5 columns]

# %%
# remove rows that contain NaN
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
df = df.dropna(axis=0)

# %%
df
# Out:
#      Year  Week       Date   Need States  Trade Spend
# 0    2021     1 2021-01-04  Need State 1         5552
# 1    2021     1 2021-01-04  Need State 2        14264
# 2    2021     1 2021-01-04  Need State 3         1563
# 3    2021     1 2021-01-04  Need State 4        18716
# 4    2021     1 2021-01-04  Need State 5         5075
# ..    ...   ...        ...           ...          ...
# 740  2023    50 2023-12-11  Need State 1        15705
# 741  2023    50 2023-12-11  Need State 2         4216
# 742  2023    50 2023-12-11  Need State 3         6644
# 743  2023    50 2023-12-11  Need State 4         2088
# 744  2023    50 2023-12-11  Need State 5          538
#
# [745 rows x 5 columns]

# %%
# check how the graphs look now
sns.lineplot(data = df, x=df.Date, y='Trade Spend')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
sns.lineplot(data = df, x='Week', y='Trade Spend', hue='Year')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
# write the dataframe to a csv file
df.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\clean\\Total Trade Spend.csv')

# %% [markdown]
# # NOTE Differences from other files:
# - Contains no data for Need State 6
# - Contains data for Weeks 42, 43, 46, and 50 in 2023

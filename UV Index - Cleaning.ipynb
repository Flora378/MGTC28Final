# %%
import pandas as pd
import seaborn as sns

# %%
# upload data
df = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\result.csv')

# %%
df
# Out:
#             Y       X  uv_index_hourly_average  \
# 0       53.55 -114.11                 0.245562
# 1       53.55 -114.11                 0.024375
# 2       53.55 -114.11                 0.089713
# 3       53.55 -114.11                 0.118058
# 4       53.55 -114.11                 0.196383
# ...       ...     ...                      ...
# 199995  79.99  -85.93                 0.287040
# 199996  82.50  -62.32                 0.114320
# 199997  82.50  -62.32                 0.012056
# 199998  82.50  -62.32                 0.005240
# 199999  82.50  -62.32                 0.041973
#
#                                                       url   dataset  \
# 0       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 1       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 2       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# 3       http://woudc.org/archive/Archive-NewFormat/Spe...  Spectral
# ...

# %%
# check if everything is the right type
df.dtypes
# Out:
# Y                          float64
# X                          float64
# uv_index_hourly_average    float64
# url                         object
# dataset                     object
# instance_datetime           object
# platform_id                  int64
# platform_name               object
# country                     object
# gaw_id                      object
# instrument_name             object
# instrument_model            object
# instrument_number            int64
# uv_index_qa                 object
# instance_hour                int64
# platform_type               object
# data_payload_id              int64
# latest_observation           int64
# uv_index_daily_max         float64
# agency                      object
# dtype: object

# %%
# take only the columns we need
df_uv = df[['instance_datetime', 'platform_name', 'uv_index_daily_max', 'uv_index_hourly_average']]

# %%
df_uv
# Out:
#           instance_datetime platform_name  uv_index_daily_max  \
# 0       2016/12/31 00:00:00      Edmonton            0.245562
# 1       2016/12/31 00:00:00      Edmonton            0.245562
# 2       2016/12/31 00:00:00      Edmonton            0.245562
# 3       2016/12/31 00:00:00      Edmonton            0.245562
# 4       2016/12/31 00:00:00      Edmonton            0.245562
# ...                     ...           ...                 ...
# 199995  2008/04/02 00:00:00        Eureka            0.493200
# 199996  2008/04/02 00:00:00         Alert            0.386250
# 199997  2008/04/02 00:00:00         Alert            0.386250
# 199998  2008/04/02 00:00:00         Alert            0.386250
# 199999  2008/04/02 00:00:00         Alert            0.386250
#
#         uv_index_hourly_average
# 0                      0.245562
# 1                      0.024375
# 2                      0.089713
# 3                      0.118058
# 4                      0.196383
# ...

# %%
# save to computer -- import to Tableau for graphing
df_uv.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\UV Index Data Cleaned.csv', index=False)

# %% [markdown]
# # Extra:

# %%
sns.lineplot(data = df_uv, x='instance_datetime', y='uv_index_hourly_average', hue='platform_name')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
sns.lineplot(data = df_uv, x='instance_datetime', y='uv_index_hourly_average')
# Out:
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# D:\Apps\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
pd.unique(df_uv['platform_name'])
# Out:
# array(['Edmonton', 'Resolute', 'Churchill', 'Toronto', 'Saturna Island',
#        'Eureka', 'Alert', 'Goose Bay', 'Toronto Atmospheric Observatory'],
#       dtype=object)

# %%
df_uv.describe()
# Out:
#        uv_index_daily_max  uv_index_hourly_average
# count       200000.000000            200000.000000
# mean             2.608435                 1.034804
# std              2.173022                 1.437801
# min              0.000120                 0.000050
# 25%              0.791440                 0.093324
# 50%              1.973360                 0.427970
# 75%              4.052280                 1.368114
# max             10.057800                10.057800

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\anime\\Desktop\\Kenvue_Final\\kenvue_data\\Total Ecomm POS (Factory $) - UTSC Lecture.csv')

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1  Fiscal Week  Fiscal Week.1  Fiscal Week.2  \
# 0     Need State  Fiscal Year         1.00           2.00           3.00
# 1   Need State 1         2021      3684.75        3426.75        4221.75
# 2   Need State 1         2022      3441.75        3657.00        3806.25
# 3   Need State 1         2023      2901.75        2919.75        2760.75
# 4   Need State 2         2021     11283.00       12698.25       18210.00
# 5   Need State 2         2022      8566.50       11636.25        9718.50
# 6   Need State 2         2023      7915.50        7142.25        7864.50
# 7   Need State 3         2021     11958.75       11279.25        9659.25
# 8   Need State 3         2022      8359.50        7750.50        6705.00
# 9   Need State 3         2023      5179.50        8040.00        5007.75
# 10  Need State 4         2021     14755.50       16803.00       16849.50
# 11  Need State 4         2022     11095.50       17230.50       13074.75
# ...

# %%
df.columns = df.iloc[0]
df = df.reindex(df.index.drop(0)).reset_index(drop=True)
df.columns.name = None
df
# Out:
#       Need State Fiscal Year       1.0       2.0       3.0       4.0  \
# 0   Need State 1        2021   3684.75   3426.75   4221.75   2959.50
# 1   Need State 1        2022   3441.75   3657.00   3806.25   3765.75
# 2   Need State 1        2023   2901.75   2919.75   2760.75   2525.25
# 3   Need State 2        2021  11283.00  12698.25  18210.00  12725.25
# 4   Need State 2        2022   8566.50  11636.25   9718.50   9857.25
# 5   Need State 2        2023   7915.50   7142.25   7864.50   8031.00
# 6   Need State 3        2021  11958.75  11279.25   9659.25  11369.25
# 7   Need State 3        2022   8359.50   7750.50   6705.00   8472.00
# 8   Need State 3        2023   5179.50   8040.00   5007.75   5653.50
# 9   Need State 4        2021  14755.50  16803.00  16849.50  14108.25
# 10  Need State 4        2022  11095.50  17230.50  13074.75  11168.25
# 11  Need State 4        2023   6963.00   8859.75   8436.00   7923.75
# 12  Need State 5        2021    448.50    285.75    276.00    237.75
# ...

# %%
df2 = pd.melt(df, id_vars=["Need State", "Fiscal Year"], var_name="Fiscal Week", value_name="Ecomm POS")

# %%
df2
# Out:
#        Need State Fiscal Year Fiscal Week  Ecomm POS
# 0    Need State 1        2021         1.0    3684.75
# 1    Need State 1        2022         1.0    3441.75
# 2    Need State 1        2023         1.0    2901.75
# 3    Need State 2        2021         1.0   11283.00
# 4    Need State 2        2022         1.0    8566.50
# ..            ...         ...         ...        ...
# 931  Need State 5        2022        52.0     795.75
# 932  Need State 5        2023        52.0       0.00
# 933  Need State 6        2021        52.0    5531.25
# 934  Need State 6        2022        52.0    5622.75
# 935  Need State 6        2023        52.0       0.00
#
# [936 rows x 4 columns]

# %%
df2['Fiscal Week'] = df2['Fiscal Week'].astype(int)
df2
# Out:
#        Need State Fiscal Year  Fiscal Week  Ecomm POS
# 0    Need State 1        2021            1    3684.75
# 1    Need State 1        2022            1    3441.75
# 2    Need State 1        2023            1    2901.75
# 3    Need State 2        2021            1   11283.00
# 4    Need State 2        2022            1    8566.50
# ..            ...         ...          ...        ...
# 931  Need State 5        2022           52     795.75
# 932  Need State 5        2023           52       0.00
# 933  Need State 6        2021           52    5531.25
# 934  Need State 6        2022           52    5622.75
# 935  Need State 6        2023           52       0.00
#
# [936 rows x 4 columns]

# %%
df2['date'] = pd.to_datetime(df2["Fiscal Year"].astype(str) + "-" + df2["Fiscal Week"].astype(str) + "-1", format='%Y-%U-%w')

# %%
df2
# Out:
#        Need State Fiscal Year  Fiscal Week  Ecomm POS       date
# 0    Need State 1        2021            1    3684.75 2021-01-04
# 1    Need State 1        2022            1    3441.75 2022-01-03
# 2    Need State 1        2023            1    2901.75 2023-01-02
# 3    Need State 2        2021            1   11283.00 2021-01-04
# 4    Need State 2        2022            1    8566.50 2022-01-03
# ..            ...         ...          ...        ...        ...
# 931  Need State 5        2022           52     795.75 2022-12-26
# 932  Need State 5        2023           52       0.00 2023-12-25
# 933  Need State 6        2021           52    5531.25 2021-12-27
# 934  Need State 6        2022           52    5622.75 2022-12-26
# 935  Need State 6        2023           52       0.00 2023-12-25
#
# [936 rows x 5 columns]

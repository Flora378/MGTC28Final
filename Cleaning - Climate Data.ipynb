# %%
import pandas as pd

# %%
# upload data
df = pd.read_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\climate-daily.csv')

# %%
df
# Out:
#          x          y SPEED_MAX_GUST_FLAG           LOCAL_DATE  LOCAL_YEAR  \
# 0    -79.4  43.666667                   M  2002-06-04 00:00:00        2002
# 1    -79.4  43.666667                   M  2002-06-05 00:00:00        2002
# 2    -79.4  43.666667                   M  2002-06-06 00:00:00        2002
# 3    -79.4  43.666667                   M  2002-06-07 00:00:00        2002
# 4    -79.4  43.666667                   M  2002-06-08 00:00:00        2002
# ...    ...        ...                 ...                  ...         ...
# 7837 -79.4  43.666667                   M  2023-11-21 00:00:00        2023
# 7838 -79.4  43.666667                   M  2023-11-22 00:00:00        2023
# 7839 -79.4  43.666667                   M  2023-11-23 00:00:00        2023
# 7840 -79.4  43.666667                   M  2023-11-24 00:00:00        2023
# 7841 -79.4  43.666667                   M  2023-11-25 00:00:00        2023
#
# ...

# %%
df_clean = df

# %%
# set 'LOCAL_DATE' to match the format of the dates in 'All Merged.csv'
df_clean['LOCAL_DATE'] = pd.to_datetime(df["LOCAL_DATE"].astype(str))

# %%
df_clean
# Out:
#          x          y SPEED_MAX_GUST_FLAG LOCAL_DATE  LOCAL_YEAR  \
# 0    -79.4  43.666667                   M 2002-06-04        2002
# 1    -79.4  43.666667                   M 2002-06-05        2002
# 2    -79.4  43.666667                   M 2002-06-06        2002
# 3    -79.4  43.666667                   M 2002-06-07        2002
# 4    -79.4  43.666667                   M 2002-06-08        2002
# ...    ...        ...                 ...        ...         ...
# 7837 -79.4  43.666667                   M 2023-11-21        2023
# 7838 -79.4  43.666667                   M 2023-11-22        2023
# 7839 -79.4  43.666667                   M 2023-11-23        2023
# 7840 -79.4  43.666667                   M 2023-11-24        2023
# 7841 -79.4  43.666667                   M 2023-11-25        2023
#
#      HEATING_DEGREE_DAYS_FLAG  TOTAL_PRECIPITATION  SNOW_ON_GROUND  \
# 0                         NaN                  4.8             NaN
# ...

# %%
# save to computer -- import to Tableau for graphing
df_clean.to_csv('D:\\Minda\\School\\University\\3 rd Year (2022-\\4 - Fall 2023 Semester\\MGTC28H3 - LEC 01\\Group Project - Nov 28\\data\\analysis\\Climate Data.csv', index=False)
